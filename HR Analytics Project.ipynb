# %% [markdown]
# ## HR Analytics Project- Understanding the Attrition in HR

# %% [markdown]
# ### Problem Statement:

# %% [markdown]
# #### Every year a lot of companies hire a number of employees. The companies invest time and money in training those employees, not just this but there are training programs within the companies for their existing employees as well. The aim of these programs is to increase the effectiveness of their employees. But where HR Analytics fit in this? and is it just about improving the performance of employees?

# %% [markdown]
# ### HR Analytics

# %% [markdown]
# #### Human resource analytics (HR analytics) is an area in the field of analytics that refers to applying analytic processes to the human resource department of an organization in the hope of improving employee performance and therefore getting a better return on investment. HR analytics does not just deal with gathering data on employee efficiency. Instead, it aims to provide insight into each process by gathering data and then using it to make relevant decisions about how to improve these processes.

# %% [markdown]
# ### Attrition in HR

# %% [markdown]
# #### Attrition in human resources refers to the gradual loss of employees overtime. In general, relatively high attrition is problematic for companies. HR professionals often assume a leadership role in designing company compensation programs, work culture, and motivation systems that help the organization retain top employees.

# %% [markdown]
# #### How does Attrition affect companies? and how does HR Analytics help in analyzing attrition? We will discuss the first question here and for the second question, we will write the code and try to understand the process step by step.

# %% [markdown]
# ### Attrition affecting Companies

# %% [markdown]
# #### A major problem in high employee attrition is its cost to an organization. Job postings, hiring processes, paperwork, and new hire training are some of the common expenses of losing employees and replacing them. Additionally, regular employee turnover prohibits your organization from increasing its collective knowledge base and experience over time. This is especially concerning if your business is customer-facing, as customers often prefer to interact with familiar people. Errors and issues are more likely if you constantly have new workers.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Read the dataset
data = pd.read_csv(r"C:\Users\ROHIT RAJAN\Downloads\ibm-hr-analytics-employee-attrition-performance\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Finding out the Age distribution of employees in IBM

# %% [markdown]
# ## Exploring Attrition by age

# %%
plt.figure(figsize=(5,8))
plt.scatter(x='Attrition',y='Age',data=data,color='black')
plt.xlabel("Attrition")
plt.ylabel("Age")
plt.title("Attrition by age",fontsize=14)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Age",data=data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x="Age",data=data,hue='Attrition')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %% [markdown]
# #### As we can see from above graph and understand the attrittion and age in the dataset

# %% [markdown]
# ## Exploring data of employees who left

# %%
plt.figure(figsize=(5,8))
sns.countplot(x="Attrition",data=data)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
# another way in matplotlib if we want a horizontal bar plot

data.Attrition.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Finding out the distribution of employees by the education field

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='EducationField',data=data)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# ## Creating barchart for married and unmarried employees

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='MaritalStatus',data=data)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
data.MaritalStatus.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,8))
data.MaritalStatus.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Contructing a logistic regression model to predict which employees are likely to attrite

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# ### As we can observe above (OverTime,Over18,Attrition,BusinessTravel,Department) all are object types database.

# %% [markdown]
# ### We can built a Machine Learning Model now as we have to change the string values to numeric values

# %%
data['Department'].value_counts() #before
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data['Department'].replace('Research & Development',1,inplace=True)
data['Department'].replace('Sales',2,inplace=True)
data['Department'].replace('Human Resources',3,inplace=True)

# %%
data['Department'].dtypes
# Out:
# dtype('int64')

# %%
data["Department"].value_counts() #after
# Out:
# 1    961
# 2    446
# 3     63
# Name: Department, dtype: int64

# %%
data['EducationField'].value_counts() #before
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
data['EducationField'].replace('Life Sciences',1,inplace=True)
data['EducationField'].replace('Medical',2,inplace=True)
data['EducationField'].replace('Marketing',3,inplace=True)
data['EducationField'].replace('Technical Degree',4,inplace=True)
data['EducationField'].replace('Other',5,inplace=True)
data['EducationField'].replace('Human Resources',6,inplace=True)

# %%
data['EducationField'].value_counts() #after
# Out:
# 1    606
# 2    464
# 3    159
# 4    132
# 5     82
# 6     27
# Name: EducationField, dtype: int64

# %%
data['MaritalStatus'].value_counts() #before
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
data['MaritalStatus'].replace('Married',1,inplace=True)
data['MaritalStatus'].replace('Single',2,inplace=True)
data['MaritalStatus'].replace('Divorced',3,inplace=True)

# %%
data['MaritalStatus'].value_counts() #after
# Out:
# 1    673
# 2    470
# 3    327
# Name: MaritalStatus, dtype: int64

# %%
data.describe()
# Out:
#                Age    DailyRate   Department  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810   802.485714     1.389116          9.192517     2.912925
# std       9.135373   403.509100     0.568893          8.106864     1.024165
# min      18.000000   102.000000     1.000000          1.000000     1.000000
# 25%      30.000000   465.000000     1.000000          2.000000     2.000000
# 50%      36.000000   802.000000     1.000000          7.000000     3.000000
# 75%      43.000000  1157.000000     2.000000         14.000000     4.000000
# max      60.000000  1499.000000     3.000000         29.000000     5.000000
#
#        EducationField  EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  \
# count     1470.000000         1470.0     1470.000000              1470.000000
# mean         2.116327            1.0     1024.865306                 2.721769
# ...

# %%
pd.crosstab(data['Attrition'],data['JobRole'])
# Out:
# JobRole    Healthcare Representative  Human Resources  Laboratory Technician  \
# Attrition
# No                               122               40                    197
# Yes                                9               12                     62
#
# JobRole    Manager  Manufacturing Director  Research Director  \
# Attrition
# No              97                     135                 78
# Yes              5                      10                  2
#
# JobRole    Research Scientist  Sales Executive  Sales Representative
# Attrition
# No                        245              269                    50
# Yes                        47               57                    33

# %%
data.Attrition.replace(('Yes','No'),(1,0),inplace=True)

# %%
#displaying the changed data

data.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0   41          1      Travel_Rarely       1102           2                 1
# 1   49          0  Travel_Frequently        279           1                 8
# 2   37          1      Travel_Rarely       1373           1                 2
# 3   33          0  Travel_Frequently       1392           1                 3
# 4   27          0      Travel_Rarely        591           1                 2
#
#    Education  EducationField  EmployeeCount  EmployeeNumber  ...  \
# 0          2               1              1               1  ...
# 1          1               1              1               2  ...
# 2          2               5              1               4  ...
# 3          4               1              1               5  ...
# 4          1               2              1               7  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
#printing the number of rows and columns in data

data.shape
# Out:
# (1470, 35)

# %%
#checking the data types of columns 

data.dtypes
# Out:
# Age                          int64
# Attrition                    int64
# BusinessTravel              object
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#looking for null values 

data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Filling the 'NumCompaniesWorked' with mean

# %%
mean_value = data['NumCompaniesWorked'].mean()
data['NumCompaniesWorked']=data['NumCompaniesWorked'].fillna(mean_value)

# %% [markdown]
# ### Filling the "TotalWorkingYears" with mean

# %%
mean_value = data['TotalWorkingYears'].mean()
data['TotalWorkingYears']=data['TotalWorkingYears'].fillna(mean_value)

# %%
#Again checking the null values 

data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Making sure that there is no null values 

data.isnull().values.any()
# Out:
# False

# %%
#Describing the data again 

data.describe()
# Out:
#                Age    Attrition    DailyRate   Department  DistanceFromHome  \
# count  1470.000000  1470.000000  1470.000000  1470.000000       1470.000000
# mean     36.923810     0.161224   802.485714     1.389116          9.192517
# std       9.135373     0.367863   403.509100     0.568893          8.106864
# min      18.000000     0.000000   102.000000     1.000000          1.000000
# 25%      30.000000     0.000000   465.000000     1.000000          2.000000
# 50%      36.000000     0.000000   802.000000     1.000000          7.000000
# 75%      43.000000     0.000000  1157.000000     2.000000         14.000000
# max      60.000000     1.000000  1499.000000     3.000000         29.000000
#
#          Education  EducationField  EmployeeCount  EmployeeNumber  \
# count  1470.000000     1470.000000         1470.0     1470.000000
# mean      2.912925        2.116327            1.0     1024.865306
# std       1.024165        1.289616            0.0      602.024335
# ...

# %%
#Checking for the unique values in column 'EmployeeCount'

data['EmployeeCount'].unique()
# Out:
# array([1], dtype=int64)

# %%
#Dropping columns 'EmployeeCount' and 'StandardHours'

data = data.drop('EmployeeCount',axis = 1)
data = data.drop('StandardHours',axis = 1)

# %% [markdown]
# ###  Creating a plot figure to analyse....

# %%
plt.figure(figsize=(8,5))
plt.hist(x='Age',data=data) # using histogram plots
plt.xlabel("Age")
plt.ylabel("No of employees")
plt.title("Age Distribution",fontsize=14)
plt.show()

# %% [markdown]
# ### Correlation matrix

# %%
data.corr()
# Out:
#                                Age  DailyRate  Department  DistanceFromHome  \
# Age                       1.000000   0.010661   -0.007652         -0.001686
# DailyRate                 0.010661   1.000000   -0.021959         -0.004985
# Department               -0.007652  -0.021959    1.000000          0.002196
# DistanceFromHome         -0.001686  -0.004985    0.002196          1.000000
# Education                 0.208034  -0.016806    0.019636          0.021042
# EducationField           -0.030912  -0.023428    0.253737          0.006907
# EmployeeCount                  NaN        NaN         NaN               NaN
# EmployeeNumber           -0.010145  -0.050990    0.057663          0.032916
# EnvironmentSatisfaction   0.010146   0.018355   -0.026110         -0.016075
# HourlyRate                0.024287   0.023381   -0.021528          0.031131
# JobInvolvement            0.029820   0.046135   -0.017693          0.008783
# ...

# %%
corr_matrix = data.corr()
f , ax = plt.subplots(figsize=(20,14))
sns.heatmap(corr_matrix, vmax=1, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Building up Logistic Regression Model

# %%
# plotting correlation heatmap
fig, ax = plt.subplots(figsize=(30,10)) 
mask = np.triu(np.ones_like(data.corr()))
dataplot = sns.heatmap(data.corr(), cmap="YlGnBu", annot=True,mask=mask,annot_kws={'size': 13},ax=ax)
# displaying heatmap
plt.show()

# %%
# Importing label encoder and converting nonnumerical values into numerical values 
import warnings
warnings.filterwarnings("ignore")
from sklearn.preprocessing import LabelEncoder
for column in data.columns:
    if data[column].dtype == np.number:
        continue
    data[column] = LabelEncoder().fit_transform(data[column])

# %%
#moving the Age from the first column to the last column

data['Age_years'] = data['Age']

# %%
data = data.drop('Age', axis = 1)

# %%
data
# Out:
#       Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0             1               3        624           1                 0
# 1             0               2        113           0                 7
# 2             1               3        805           0                 1
# 3             0               2        820           0                 2
# 4             0               3        312           0                 1
# ...         ...             ...        ...         ...               ...
# 1465          0               2        494           0                22
# 1466          0               3        327           0                 5
# 1467          0               3         39           0                 3
# 1468          0               2        579           1                 1
# 1469          0               3        336           0                 7
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# ...

# %% [markdown]
# ###  Preparig Data

# %%
X = data.iloc[:, 1:data.shape[1]].values
Y = data.iloc[:, 0].values

# %% [markdown]
# ### Splitting the data into trianing data and testing data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ### Building model using RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 10 , criterion = 'entropy', random_state = 0)
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %% [markdown]
# ### Checking the accuracy of our model

# %%
 
forest.score(X_train, Y_train)
# Out:
# 0.9809437386569873
